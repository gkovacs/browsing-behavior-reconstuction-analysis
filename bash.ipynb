# %%
# this is with the new reconstruction method
#time python reconstruct_focus_times_v2.py
#python -m cProfile -s cumulative reconstruct_focus_times_v2.py
#python -m cProfile -s cumulative reconstruct_spans_persecond.py

#python tmilib_scratch.py
# Out:
# secondlevel_activespan_dataset_insession_for_user/slQSVAoKw9.json
# secondlevel_activespan_dataset_insession_for_user/oHo0KJayR3.json
# secondlevel_activespan_dataset_insession_for_user/LvC0lAqsGl.json
# secondlevel_activespan_dataset_insession_for_user/y9A3KNc4L2.json
# secondlevel_activespan_dataset_insession_for_user/ZqYweFWTDB.json
# secondlevel_activespan_dataset_insession_for_user/afgJ51Bm3L.json
# secondlevel_activespan_dataset_insession_for_user/gbgBvBTCas.json
# secondlevel_activespan_dataset_insession_for_user/BDVuS6fgAX.json
# secondlevel_activespan_dataset_insession_for_user/sbYaq0dCm3.json
# secondlevel_activespan_dataset_insession_for_user/8K1lT7ZHFv.json
# secondlevel_activespan_dataset_insession_for_user/moXagAxvWy.json
# secondlevel_activespan_dataset_insession_for_user/6dD811RitI.json
# secondlevel_activespan_dataset_insession_for_user/nE6tllU9R5.json
# secondlevel_activespan_dataset_insession_for_user/dvi2exM01v.json
# ...

# %%
# this is with the old reconstruction method
#time python reconstruct_focus_times_v2.py
# Out:
#              precision    recall  f1-score   support
#
#       False       0.84      0.39      0.54     16530
#        True       0.98      1.00      0.99    435859
#
# avg / total       0.97      0.98      0.97    452389
#
# correct span 0.859318789052 of ref_active_time
# ref_inactive_but_rec_active 0.53097847811 of ref_active_time
# correct url 0.598110786191 of ref_active_time 0.696028986927 of correct_span
# Counter({'both_inactive': 907153, 'correct_url': 28430, 'ref_inactive_but_rec_active': 25239, 'incorrect_domain': 10113, 'ref_active_but_rec_inactive': 6687, 'correct_domain': 2303})
# correct span 0.760497689888 of ref_active_time
# ref_inactive_but_rec_active 0.267548702128 of ref_active_time
# correct url 0.466483544556 of ref_active_time 0.613392454388 of correct_span
# Counter({'both_inactive': 7946942, 'correct_url': 958668, 'ref_inactive_but_rec_active': 549838, 'ref_active_but_rec_inactive': 492200, 'incorrect_domain': 488439, 'correct_domain': 115788})
# ...
