# %%
from tmilib import *
from h2o_utils import *

import h2o
h2o.init()
# Out:
# /afs/.ir.stanford.edu/users/g/k/gkovacs/ve/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /afs/.ir.stanford.edu/users/g/k/gkovacs/ve/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /afs/.ir.stanford.edu/users/g/k/gkovacs/ve/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# ...

# %%
import traceback

# %%
classifier = load_h2o_model('binclassifier_catfeatures_randomforest_second_v6.h2o')
print classifier
# Out:
# Model Details
# ...
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  DRF_model_python_1460365816027_1
#
# Model Summary:
#     number_of_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     50                 4.18696e+07            20           20           20            49025         83403         72362.3
# ModelMetricsBinomial: drf
# ** Reported on train data. **
#
# MSE: 0.0269062202654
# R^2: 0.771111575567
# LogLoss: 0.0856634392885
# AUC: 0.990947729803
# Gini: 0.981895459606
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.42519878583:
#        F            T            Error    Rate
# -----  -----------  -----------  -------  -----------------------
# F      1.02124e+08  3.28152e+06  0.0311   (3281521.0/105405709.0)
# ...

# %%
make_predictions_and_save(classifier, 'catdata_test_insession_second_evaluation_v4.csv', 'catdata_test_insession_second_evaluation_predictions_datav4_modelv6.csv', 3)
# Out:
# Parse Progress: [##################################################] 100%
#
# drf prediction Progress: [##################################################] 100%

# %%
make_predictions_and_save(classifier, 'catdata_test_second_evaluation_v4.csv', 'catdata_test_second_evaluation_predictions_datav4_modelv6.csv', 3)
# Out:
# Parse Progress: [##################################################] 100%
#
# drf prediction Progress: [##################################################] 100%

# %%
test_data_insession = load_h2o_data('catdata_test_insession_second_v4.csv')
classifier.model_performance(test_data_insession)
# Out:
# Parse Progress: [##################################################] 100%
#
# ModelMetricsBinomial: drf
# ** Reported on test data. **
#
# MSE: 0.135256981527
# R^2: 0.439751328104
# LogLoss: 0.416001379228
# AUC: 0.884766256702
# Gini: 0.769532513404
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.445983639243:
#        F            T            Error    Rate
# -----  -----------  -----------  -------  ----------------------
# F      6.75107e+06  2.75478e+06  0.2898   (2754782.0/9505854.0)
# T      1.92955e+06  1.18982e+07  0.1395   (1929546.0/13827777.0)
# Total  8.68062e+06  1.4653e+07   0.2008   (4684328.0/23333631.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                      threshold    value     idx
# --------------------------  -----------  --------  -----
# max f1                      0.445984     0.835527  227
# max f2                      0.173022     0.891873  336
# max f0point5                0.718951     0.860562  130
# ...
