# %%
from tmilib import *
from h2o_utils import *

import h2o
h2o.init()
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# ...

# %%
import traceback

# %%
classifier = load_h2o_model('binclassifier_catfeatures_randomforest_second_v6_mtries_1_sample_rate_0.9.h2o')
print classifier
# Out:
# Model Details
# ...
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  DRF_model_python_1460365816027_25
#
# Model Summary:
#     number_of_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     50                 4.5493e+06             20           20           20            2520          14852         7849.84
# ModelMetricsBinomial: drf
# ** Reported on train data. **
#
# MSE: 0.0350739124406
# R^2: 0.701631232581
# LogLoss: 0.116677163796
# AUC: 0.983959105939
# Gini: 0.967918211878
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4020991866:
#        F            T            Error    Rate
# -----  -----------  -----------  -------  -----------------------
# F      1.00996e+08  3.88441e+06  0.037    (3884413.0/104880074.0)
# ...

# %%
test_data_insession = load_h2o_data('catdata_test_insession_second.csv')
classifier.model_performance(test_data_insession)
# Out:
# Parse Progress: [##################################################] 100%
#
# ModelMetricsBinomial: drf
# ** Reported on test data. **
#
# MSE: 0.135912543531
# R^2: 0.437035921196
# LogLoss: 0.427233206061
# AUC: 0.888618189061
# Gini: 0.777236378122
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.405511165157:
#        F            T            Error    Rate
# -----  -----------  -----------  -------  ----------------------
# F      6.79252e+06  2.71334e+06  0.2854   (2713335.0/9505854.0)
# T      1.81388e+06  1.20139e+07  0.1312   (1813876.0/13827777.0)
# Total  8.6064e+06   1.47272e+07  0.194    (4527211.0/23333631.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                      threshold    value     idx
# --------------------------  -----------  --------  -----
# max f1                      0.405511     0.841457  247
# max f2                      0.163636     0.895255  340
# max f0point5                0.597924     0.858591  170
# ...
